# %% [markdown]
# <a href="https://colab.research.google.com/github/JHORIZ-RODEL-AQUINO/CPEN65-2/blob/main/Graphs_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2023-01-11_224845339.png](data:image/png;base64,...)

# %% [markdown]
# Outdegree of:
# > 1 is 2
#
# > 2 is 2
#
# > 3 is 0
#
# > 4 is 0
#
# > 5 is 2
#
# > 6 is 2

# %% [markdown]
# Indegree of:
# > 1 is 2
#
# > 2 is 1
#
# > 3 is 1
#
# > 4 is 2
#
# > 5 is 1
#
# > 6 is 1

# %% [markdown]
# Node 1 is adjacent to nodes 2 and 5
#
# Node 2 is adjacent to nodes 1 and 4
#
# Node 5 is adjacent to nodes 4 and 6
#
# Node 6 is adjacent to nodes 1 and 3

# %% [markdown]
# Node 1 is adjacent from nodes 2 and 6
#
# Node 2 is adjacent to from node 1
#
# Node 3 is adjacent from node 6
#
# Node 4 is adjacent from nodes 2 and 5
#
# Node 5 is adjacent from node 1
#
# Node 6 is adjacent from node 5

# %% [markdown]
# Simple Paths:
# * 1-2
# * 1-2-4
# * 2-1
# * 2-1-5
# * 2-1-5-4
# * 5-4
# * 5-6
# * 5-6-1
# * 5-6-1-2
# * 5-6-1-2-4
# * 6-3
# * 6-1
# * 6-1-2
# * 6-1-2-4

# %% [markdown]
# Simple Cycles:
# * 1-2-1
# * 2-1-2
# * 1-5-6-1
# * 5-6-1-5
# * 6-1-5-6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Outdegree of:
# > 1 is 1
#
# > 2 is 2
#
# > 3 is 2
#
# > 4 is 3
#
# > 5 is 1

# %% [markdown]
# Indegree of:
# > 1 is 3
#
# > 2 is 1
#
# > 3 is 1
#
# > 4 is 2
#
# > 5 is 2

# %% [markdown]
# Node 1 is adjacent to node 4
#
# Node 2 is adjacent to nodes 1 and 5
#
# Node 3 is adjacent to nodes 1 and 4
#
# Node 4 is adjacent to nodes 1, 3 and 5
#
# Node 5 is adjacent to node 2

# %% [markdown]
# Node 1 is adjacent from nodes 2, 3 and 4
#
# Node 2 is adjacent to from node 5
#
# Node 3 is adjacent from node 4
#
# Node 4 is adjacent from nodes 1 and 3
#
# Node 5 is adjacent from nodes 2 and 4

# %% [markdown]
# Simple Paths:
# * 1-4
# * 1-4-3
# * 1-4-5
# * 1-4-5-2
# * 2-1
# * 2-1-4
# * 2-1-4-3
# * 2-1-4-5
# * 3-1
# * 3-1-4
# * 3-1-4-5
# * 3-1-4-5-2
# * 4-1
# * 4-3
# * 4-3-1
# * 4-5
# * 4-5-2
# * 4-5-2-1
# * 5-2
# * 5-2-1
# * 5-2-1-4
# * 5-2-1-4-3

# %% [markdown]
# Simple Cycles:
# * 1-4-1
# * 1-4-3-1
# * 1-4-5-2-1
# * 2-5-2
# * 2-1-4-5-2
# * 3-4-3
# * 3-1-4-3
# * 4-1-4
# * 4-3-4
# * 4-3-1-4
# * 5-2-5
# * 5-2-1-4-5
